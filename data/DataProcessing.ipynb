# %% [markdown]
# # Data Processing

# %%
import pandas as pd

file_name = "RING_SAATLERI.xlsx"

# %%
dfs = pd.read_excel(file_name, sheet_name=None)

# %%
dfs["HAFTA SONU"]
# Out:
#    RİNG 1 - HAFTA SONU Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0                 1100       1030       1050        960        950        810
# 1             07:00:00   07:04:00   07:06:00   07:07:00   07:08:00   07:08:00
# 2             07:20:00   07:24:00   07:26:00   07:27:00   07:28:00   07:28:00
# 3             07:40:00   07:44:00   07:46:00   07:47:00   07:48:00   07:48:00
# 4             08:00:00   08:04:00   08:06:00   08:07:00   08:08:00   08:08:00
# ..                 ...        ...        ...        ...        ...        ...
# 84            20:30:00   20:31:00   20:32:00   20:33:00   20:34:00   20:35:00
# 85            21:00:00   21:01:00   21:02:00   21:03:00   21:04:00   21:05:00
# 86            21:30:00   21:31:00   21:32:00   21:33:00   21:34:00   21:35:00
# 87            22:00:00   22:01:00   22:02:00   22:03:00   22:04:00   22:05:00
# 88            22:30:00   22:31:00   22:32:00   22:33:00   22:34:00   22:35:00
#
# ...
