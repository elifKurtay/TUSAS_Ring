# %% [markdown]
# # Data Processing

# %%
import pandas as pd
import numpy as np

file_name = "RING_SAATLERI.xlsx"

# %%
dfs = pd.read_excel(file_name, sheet_name=None)

# %%
df = dfs["HAFTA SONU"]

# ring 1
df1 = df.iloc[1:43]
df1.columns = df.iloc[0]
df1.reset_index(drop=True, inplace=True)

# ring 2
df2 = df.iloc[47:]
df2.columns = df.iloc[46]
df2 = df2.dropna(axis=1) # drops NaN valued columns
df2 = df2.drop(950, axis=1) # 950 has wrong values
df2.reset_index(drop=True, inplace=True)

# %%
# to learn row indexes with non-numerical values
df[~df.applymap(np.isreal).all(1)]
# Out:
#     RİNG 1 - HAFTA SONU Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0                  1100       1030       1050        960        950
# 45  RİNG 2 - HAFTA SONU        NaN        NaN        NaN        NaN
# 46                   G1        210        170         B5         40
#
#    Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 13  \
# 0         810         B4         B5        170        210  ...         210
# 45        NaN        NaN        NaN        NaN        NaN  ...         NaN
# 46        320        710        950        960       1050  ...         850
#
#    Unnamed: 14 Unnamed: 15 Unnamed: 16 Unnamed: 17 Unnamed: 18 Unnamed: 19  \
# 0          170          B5          B4         810         950         960
# 45         NaN         NaN         NaN         NaN         NaN         NaN
# 46         200         410         420         170         210          G1
#
#    Unnamed: 20 Unnamed: 21 Unnamed: 22
# 0         1050        1030        1100
# ...

# %%
df1.columns = ['1100', '1030', '1050', '960', '950', '810', 'B4', 'B5', '170', '210', '610', '280', 'G1', 
               '210_2', '170_2', 'B5_2', 'B4_2', '810_2', '950_2', '960_2', '1050_2', '1030_2', '1100_2']
df1
# Out:
#         1100      1030      1050       960       950       810        B4  \
# 0   07:00:00  07:04:00  07:06:00  07:07:00  07:08:00  07:08:00  07:08:00
# 1   07:20:00  07:24:00  07:26:00  07:27:00  07:28:00  07:28:00  07:28:00
# 2   07:40:00  07:44:00  07:46:00  07:47:00  07:48:00  07:48:00  07:48:00
# 3   08:00:00  08:04:00  08:06:00  08:07:00  08:08:00  08:08:00  08:08:00
# 4   08:20:00  08:24:00  08:26:00  08:27:00  08:28:00  08:28:00  08:28:00
# 5   08:40:00  08:44:00  08:46:00  08:47:00  08:48:00  08:48:00  08:48:00
# 6   09:00:00  09:04:00  09:06:00  09:07:00  09:08:00  09:08:00  09:08:00
# 7   09:20:00  09:24:00  09:26:00  09:27:00  09:28:00  09:28:00  09:28:00
# 8   09:40:00  09:44:00  09:46:00  09:47:00  09:48:00  09:48:00  09:48:00
# 9   10:00:00  10:04:00  10:06:00  10:07:00  10:08:00  10:08:00  10:08:00
# 10  10:20:00  10:24:00  10:26:00  10:27:00  10:28:00  10:28:00  10:28:00
# 11  10:40:00  10:44:00  10:46:00  10:47:00  10:48:00  10:48:00  10:48:00
# ...

# %%
df2.columns = ['G1', '210', '170', 'B5', '40', '320', '710', '960', '1050', '961', '910', '202', '850', '200', '410', '420',  
               '170_2',  '210_2', 'G1_2']
df2
# Out:
#           G1       210       170        B5        40       320       710  \
# 0   07:00:00  07:01:00  07:02:00  07:03:00  07:04:00  07:05:00  07:06:00
# 1   07:20:00  07:21:00  07:22:00  07:23:00  07:24:00  07:25:00  07:26:00
# 2   07:40:00  07:41:00  07:42:00  07:43:00  07:44:00  07:45:00  07:46:00
# 3   08:00:00  08:01:00  08:02:00  08:03:00  08:04:00  08:05:00  08:06:00
# 4   08:20:00  08:21:00  08:22:00  08:23:00  08:24:00  08:25:00  08:26:00
# 5   08:40:00  08:41:00  08:42:00  08:43:00  08:44:00  08:45:00  08:46:00
# 6   09:00:00  09:01:00  09:02:00  09:03:00  09:04:00  09:05:00  09:06:00
# 7   09:20:00  09:21:00  09:22:00  09:23:00  09:24:00  09:25:00  09:26:00
# 8   09:40:00  09:41:00  09:42:00  09:43:00  09:44:00  09:45:00  09:46:00
# 9   10:00:00  10:01:00  10:02:00  10:03:00  10:04:00  10:05:00  10:06:00
# 10  10:20:00  10:21:00  10:22:00  10:23:00  10:24:00  10:25:00  10:26:00
# 11  10:40:00  10:41:00  10:42:00  10:43:00  10:44:00  10:45:00  10:46:00
# ...

# %%
# write to JSON
df1.to_json('hs_ring1.json', orient="columns")
df2.to_json('hs_ring2.json', orient="columns")
